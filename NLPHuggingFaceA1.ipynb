# %% [markdown]
# <a href="https://colab.research.google.com/github/mivinmathew/HuggingFaceExperimentation/blob/main/NLPHuggingFaceA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NLP Assessment 1 Task 1 + Task 2 : Transformer Models for NLP and Speech Recognition

# %%
#checking version of python

# %%
# !python --version
# Out:
# Python 3.9.16

# %%
#ensure installation of HFace transformers libary

# %%
# !pip install transformers
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#install and test the pipeline import

# %%
from transformers import pipeline

# %%
translator = pipeline ("translation_en_to_de")
# Out:
# No model was supplied, defaulted to t5-base and revision 686f1db (https://huggingface.co/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
print(translator("the magic of mushrooms lies in pre-trained models"))
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1201: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# [{'translation_text': 'die Magie der Pilze liegt in vorgebildeten Modellen'}]

# %% [markdown]
# +
#
#
# #TASK 1 : Programming Tasks for NLP Frequent Use_Cases with Hugging Face Transformers
#
#
# +

# %%
#specifying "ner" as the task name when calling the pipeline function and specifying a Named Entity Recongnition (NER) model as the 'model' parameter

# %%
ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english")

# %%
#+



#pre-trained BERT model fine-tuned on the CoNLL-2003 named entity reconigition (NER) task for English



#+

# %%
#performing NER on original text

# %%
text = "Mivin is currently completing an assessment task for the subject Natural Language Processing 303, at Torrens University in Sydney, Australia"

# %%
result = ner(text)

# %%
print(result)
# Out:
# [{'entity': 'I-PER', 'score': 0.9987348, 'index': 1, 'word': 'Mi', 'start': 0, 'end': 2}, {'entity': 'I-PER', 'score': 0.9895, 'index': 2, 'word': '##vin', 'start': 2, 'end': 5}, {'entity': 'I-MISC', 'score': 0.98982084, 'index': 12, 'word': 'Natural', 'start': 65, 'end': 72}, {'entity': 'I-MISC', 'score': 0.96975225, 'index': 13, 'word': 'Language', 'start': 73, 'end': 81}, {'entity': 'I-MISC', 'score': 0.95630217, 'index': 14, 'word': 'Process', 'start': 82, 'end': 89}, {'entity': 'I-MISC', 'score': 0.98683715, 'index': 15, 'word': '##ing', 'start': 89, 'end': 92}, {'entity': 'I-MISC', 'score': 0.7645929, 'index': 16, 'word': '303', 'start': 93, 'end': 96}, {'entity': 'I-ORG', 'score': 0.9964677, 'index': 19, 'word': 'Torre', 'start': 101, 'end': 106}, {'entity': 'I-ORG', 'score': 0.9947962, 'index': 20, 'word': '##ns', 'start': 106, 'end': 108}, {'entity': 'I-ORG', 'score': 0.98766464, 'index': 21, 'word': 'University', 'start': 109, 'end': 119}, {'entity': 'I-LOC', 'score': 0.997
# ...

# %% [markdown]
# Identified entities and labels
# - Mi : Person
# - Vin  : Person
# - Natural Language Processing 303 : Miscellaneous
# - Torre : Organisation
# - Ns : Organisation
# - University : Organisation
# - Sydney : Location
# - Australia : Location

# %%
#+



#sentiment analysis pipeline, specifying the model to be used : 'distilbert-base-uncased-finetuned-sst-2-english'as recommended.



#+

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")

sentiment_analysis = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %%
result = sentiment_analysis("It was a very enjoyable and enriching learning experience working with HuggingFace Transformers")

# %%
print(result)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998558759689331}]

# %%
#testing negative sentiment

# %%
result = sentiment_analysis("For some, programming may be a tedious task and not as enjoyable - so each to their own")

# %%
print(result)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9994276165962219}]

# %%
#testing neutral sentiment

# %%
result = sentiment_analysis("There is a book on my desk")

# %%
print(result)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9236947894096375}]

# %%
#+



#summarizer pipeline using t5-base model with tokenizer instantiation 'model_max_length' 



#+

# %%
from transformers import pipeline
tokenizer = AutoTokenizer.from_pretrained("t5-base", model_max_length = 580)
summarizer = pipeline ("summarization", model = "t5-base", tokenizer = tokenizer,framework = "tf" )
# Out:
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at t5-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %%
text=("The field of natural language processing (NLP) has experienced significant progress and growth in recent years, and this trend is likely to continue in the coming years. In this response, I will discuss some of the key trends and directions in the future of NLP. One of the most important trends in NLP is the increasing use of deep learning techniques. Deep learning models, such as recurrent neural networks (RNNs) and transformers, have been shown to achieve state-of-the-art performance on a range of NLP tasks, including text classification, machine translation, and question-answering. This trend is likely to continue as researchers develop more sophisticated deep learning models and apply them to new NLP tasks.Another trend in NLP is the increasing focus on developing models that can learn from less labeled data. One approach to achieving this is through the use of unsupervised learning techniques, such as pre-training language models on large corpora of text. These pre-trained models can then be fine-tuned on smaller labeled datasets for specific NLP tasks. This approach has been shown to achieve impressive results and is likely to continue to be an important area of research in the future.In addition, the future of NLP is likely to see increased focus on developing models that can handle more complex linguistic phenomena, such as sarcasm, irony, and humor. Currently, NLP models struggle with these phenomena, and there is much work to be done to improve their performance in these areas.Another area of NLP that is likely to see significant growth in the future is the use of NLP techniques for social good. For example, NLP can be used to analyze social media data to understand public sentiment and identify important social issues. NLP can also be used to develop tools for monitoring hate speech and other harmful content online.Finally, the future of NLP is likely to see increased focus on developing models that can handle multiple languages and dialects. Currently, many NLP models are designed to work with specific languages, but there is a growing need for models that can work with multiple languages and dialects. This is particularly important for developing NLP applications for use in multilingual societies and in contexts where multiple languages are commonly used.In conclusion, the future of NLP is likely to be characterized by continued progress in deep learning techniques, increased focus on developing models that can learn from less labeled data, improved handling of complex linguistic phenomena, greater use of NLP for social good, and development of models that can handle multiple languages and dialects. These trends are likely to drive significant innovation in the field of NLP and lead to the development of new and improved NLP applications.")

# %%
#summarize into simplest form without set parameters, ideally to digest all that information at a high-level glance

# %%
result = summarizer(text, do_sample=False)

print(result[0]['summary_text'])
# Out:
# the field of natural language processing (NLP) has experienced significant progress and growth in recent years . the future of NLP is likely to see increased focus on developing models that can handle more complex linguistic phenomena .

# %%
#+



#text generation pipeline with text-generation task using model 'distilgpt2'



#+

# %%
text_generator = pipeline("text-generation",model ="distilgpt2")

# %%
#providing text generation prompt equating to 15 words and specifying text generation to have a max_length = 500 words and num_return_sequences = 1, for one outcome.
#do_sample to use sampling during text generation, set to True for more diverse and dynamic results
#text_generator function uses a list of dictionaries containing the generated text sequences

# %%
prompt = "The field of natural language processing has experienced significant progress and growth in recent years"
output = text_generator(prompt,max_length = 500,do_sample = True, num_return_sequences=1)
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1201: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
generated_text = output[0]['generated_text'].strip()
print(generated_text)
# Out:
# The field of natural language processing has experienced significant progress and growth in recent years. Although there have been several recent developments in the field of language processing research, the primary focus remains on the understanding of the impact of these developments. In addition, the literature is lacking on the relationship between the interpretation of historical and linguistic data to linguistics and linguistics across different languages and countries. However, many research findings in the field of natural language processing need to be discussed. Because of the increasing attention on the importance of interpretation of historical, linguistic and linguistic data for interpreting and interpreting, the development of the new scientific methods and practices is considered a unique way to conduct scientific research and analysis.

# %%
#+



#question_answering pipeline using DistilBERT model and tokenizer



#+

# %%
qa_pipeline = pipeline("question-answering",model="distilbert-base-cased-distilled-squad", tokenizer="distilbert-base-cased")

# %%
#defining text and question posed to extract answer

# %%
text = "The field of natural language processing has experienced significant progress and growth in recent years. Although there have been several recent developments in the field of language processing research, the primary focus remains on the understanding of the impact of these developments. In addition, the literature is lacking on the relationship between the interpretation of historical and linguistic data to linguistics and linguistics across different languages and countries."
question = " What is the primary focus in the field of language processing research?"

# %%
#extracting answer with confidence score and position of answer in given text

# %%
result = qa_pipeline({
    "context": text,
    "question" : question
})

# %%
print(f"Answer: {result['answer']}")
print(f"Confidence Score: {result['score']}")
print(f"Answer Start Position: {result['start']}")
print(f"Answer End Position: {result['end']}")
# Out:
# Answer: the understanding of the impact of these developments
# Confidence Score: 0.4381973147392273
# Answer Start Position: 234
# Answer End Position: 287

# %%
#installation of SentencePiece library for the mt5 tokenizer

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.8 MB/s eta 0:00:00
# ...

# %%
#+



#test translation pipeline : English to French using Helsinki-NLP/opus-mt-en-fr model 



#+

# %%
translator = pipeline("translation_en_to_fr", model="Helsinki-NLP/opus-mt-en-fr")
result = translator("This is a test sentence")

print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-db179a233c67> in <module>
# ----> 1 translator = pipeline("translation_en_to_fr", model="Helsinki-NLP/opus-mt-en-fr")
#       2 result = translator("This is a test sentence")
#       3
#       4 print(result)
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     871                 tokenizer_kwargs = model_kwargs
#     872
# --> 873             tokenizer = AutoTokenizer.from_pretrained(
#     874                 tokenizer_identifier, use_fast=use_fast, _from_pipeline=task, **hub_kwargs, **tokenizer_kwargs
#     875             )
#
# ...

# %%
#reinstalling sentencepiece to see if there was any error with initial install

# %%
# !pip install sentencepiece --force-reinstall
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# ...
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.1.97
#     Uninstalling sentencepiece-0.1.97:
#       Successfully uninstalled sentencepiece-0.1.97
# ...

# %%
#test again removing the model specification to restore to default t5-base, as error when attempting to use Helsinki-NLP/opus-mt-en-fr model

# %%
translator = pipeline("translation_en_to_fr")
result = translator("This is a test sentence")

print(result)
# Out:
# No model was supplied, defaulted to t5-base and revision 686f1db (https://huggingface.co/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'translation_text': "Il s'agit d'une sentence d'essai"}]

# %%
#+



#translation pipeline : English to French using 3 personally generated sentences



#+

# %%
translator = pipeline("translation_en_to_fr")
result1 = translator("My name is Mivin and I am Indian")
result2 = translator("It is fascinating learning about this life and the world we live in")
result3 = translator("Task 1 has been very eduactional and productive")
print(result1)
print(result2)
print(result3)
# Out:
# No model was supplied, defaulted to t5-base and revision 686f1db (https://huggingface.co/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# ...

# %% [markdown]
# +
#
# # TASK 2 Programming Task for NLP Transformer Solutions
#
# +

# %%
#+



#using Distilbert=base-uncased to illustarte masked language modelling



#+

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForMaskedLM

# %%
#instantiating tokenizer and model

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
model = AutoModelForMaskedLM.from_pretrained("distilbert-base-uncased")

# %%
#define the sentence with context of 5-10 words with mask, and then tokenize the sentence to find the index/position of the mask

# %%
sentence ="I went to the [MASK] to buy some milk and bread"
tokens = tokenizer.tokenize(sentence)
mask_index = tokens.index("[MASK]")

# %%
#generating predictions for MASK using pipeline

# %%
fill_mask = pipeline("fill-mask", model=model, tokenizer=tokenizer)
predictions = fill_mask(sentence)

# %%
#output top 5 options/results with scores

# %%
for prediction in predictions[:5]:
    predicted_word = prediction["token_str"]
    score = prediction["score"]
    tokens[mask_index] = predicted_word
    output_sentence = tokenizer.convert_tokens_to_string(tokens)
    print(f"{output_sentence}: {score:.2f}")
# Out:
# i went to the market to buy some milk and bread: 0.17
# i went to the bakery to buy some milk and bread: 0.08
# i went to the kitchen to buy some milk and bread: 0.05
# i went to the store to buy some milk and bread: 0.04
# i went to the supermarket to buy some milk and bread: 0.04

# %%
#+



#ProsusAI/finBERT model for stock market headline sentiment classification



#+

# %%
#importing the classes and instantiating the tokenizor and model with the model name

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("prosusai/finbert")
model = AutoModelForSequenceClassification.from_pretrained("prosusai/finbert")

# %%
#defining sentiment classification using ProsusAI/finBERT model and providing fake stock market headlines for classification

# %%
sentiment_classifier = pipeline("sentiment-analysis", model="ProsusAI/finbert")

headlines =["Tech Giant Atlassian stock soaring on positive earnings report",
            "Rokt E-Commerce collaborates with The Commonwealth Bank of Australia in unexpected merger",
            "Bank of Australia announces new interest rates due to unprecendented inflation"]

# %%
#sentiment classification for each headline

# %%
for headline in headlines:
    result = sentiment_classifier(headline)
    print(headline, ":", result[0]['label'], result[0]['score'])
# Out:
# Tech Giant Atlassian stock soaring on positive earnings report : positive 0.9333679676055908
# Rokt E-Commerce collaborates with The Commonwealth Bank of Australia in unexpected merger : positive 0.5766975283622742
# Bank of Australia announces new interest rates due to unprecendented inflation : negative 0.8949083685874939

# %%
#+



# MICROSOFT DialoGPT-large model CHAT INTERACTION 



#+

# %%
#downloading model

# %%
from transformers import AutoModelForCausalLM,AutoTokenizer
import torch
model_name="microsoft/DialoGPT-large"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# %%
#using pipeline function from transformers library as per code provided from https://huggingface.co/microsoft/DialoGPT-large?text=Hey+my+name+is+Julien%21+How+are+you%3F

# %%
for step in range(5):
    # encode the new user input, add the eos_token and return a tensor in Pytorch
    new_user_input_ids = tokenizer.encode(input(">> User:") + tokenizer.eos_token, return_tensors='pt')

    # append the new user input tokens to the chat history
    bot_input_ids = torch.cat([chat_history_ids, new_user_input_ids], dim=-1) if step > 0 else new_user_input_ids

    # generated a response while limiting the total chat history to 1000 tokens, 
    chat_history_ids = model.generate(bot_input_ids, max_length=1000, pad_token_id=tokenizer.eos_token_id)

    # pretty print last ouput tokens from bot
    print("DialoGPT: {}".format(tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)))
# Out:
# >> User:hello! how is your day going?
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# DialoGPT: Good, you?
# >> User:its been great, keen to enjoy the sunset later today, we were expecting rain but its sunny as ever.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# DialoGPT: I'm glad you're enjoying it.
# >> User:tell me about yourself
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# DialoGPT: I'm a student, and I'm doing well.
# >> User:what sort of student?
# ...

# %%
#+



# FACEBOOK Wav2Vec2-Base-960h Speech Recognition Model



#+

# %%
#importing model and capability to upload recorded wav file using torchaudio,while initialising tokenizer and model

# %%
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer

tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

import torchaudio
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# /usr/local/lib/python3.9/dist-packages/transformers/models/wav2vec2/tokenization_wav2vec2.py:752: FutureWarning: The class `Wav2Vec2Tokenizer` is deprecated and will be removed in version 5 of Transformers. Please use `Wav2Vec2Processor` or `Wav2Vec2CTCTokenizer` instead.
#   warnings.warn(
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
filename = "your_audio_file.wav"
waveform, sample_rate = torchaudio.load(filename)

#preprocess audio using tokenizer 

input_values = tokenizer(waveform, return_tensors="pt").input_values

#pass preprocessed audio through the model to get output logits

logits = model(input_values).logits

# decode logits using tokenizer to get transcribed text

transcription = tokenizer.decode(torch.argmax(logits, dim=-1))
print(transcription)



#sourced from HFace Hub same process with processor instead of tokenizer

from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
 from datasets import load_dataset
 import torch
 
 # load model and tokenizer
 processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
 model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")
     
 # load dummy dataset and read soundfiles
 ds = load_dataset("patrickvonplaten/librispeech_asr_dummy", "clean", split="validation")
 
 # tokenize
 input_values = processor(ds[0]["audio"]["array"], return_tensors="pt", padding="longest").input_values  # Batch size 1
 
 # retrieve logits
 logits = model(input_values).logits
 
 # take argmax and decode
 predicted_ids = torch.argmax(logits, dim=-1)
 transcription = processor.batch_decode(predicted_ids)
